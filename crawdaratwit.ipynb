# %%
import tweepy
from tweepy import Stream
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
import time
import json
import csv
auth = tweepy.auth.OAuthHandler('P1W0LVSTdMTjIMzKq2RVBSVlL', 
                                'yaDxp4WpoAts7MRuv8zRKzDTOzhsfBlcmBoYNtLHOFBgTEBzeT')
auth.set_access_token('1374942805886332930-UWTYUNWTRdQAf2qMWPUSoQ9toXdVNN', 
                      '8aj5oSi7Ih3v3YfEyQjGysVSEa4y1KFtG7i1UqxpaxODG')
api = tweepy.API(auth)

# %%
csvFile = open('crawvaksin.csv', 'a', encoding='utf-8')
csvWriter = csv.writer(csvFile)

# %%
for tweet in tweepy.Cursor(api.search,
                           q = "vaksin covid sinovac",
                           since = "2021-05-29",
                           until = "2021-06-04",
                           lang = "id").items(5000):

    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8')])
    print(tweet.created_at, tweet.text)
csvFile.close()
# Out:
# 2021-06-03 23:15:25 Singapura beri izin khusus vaksin COVID-19 Sinovac
#
# https://t.co/AuAXFD4AmJ
# 2021-06-03 22:59:46 RT @SinarOnline: Setakat ini, dua jenis vaksin China telah diluluskan penggunaannya oleh WHO, iaitu vaksin Sinopharm dan Sinovac. #sinarhar…
# 2021-06-03 18:40:07 RT @Ahmad_hendars: "Semoga ini bisa membantu masyarakat Indonesia untuk melakukan perjalanan di dalam negeri atau luar negeri," kata Erick…
# 2021-06-03 18:38:08 RT @Ahmad_hendars: "Semoga ini bisa membantu masyarakat Indonesia untuk melakukan perjalanan di dalam negeri atau luar negeri," kata Erick…
# 2021-06-03 17:35:45 RT @erickthohir: Alhamdulillah, kemarin WHO mengeluarkan izin penggunaan darurat (EUL) untuk vaksin COVID-19 produksi Sinovac, menyusul izi…
# 2021-06-03 17:19:47 RT @HausofHilton: 2/3 daripada penduduk di Serenna, Brazil sudah menerima kedua dua dos vaksin Sinovac
#
# Dan Kadar kematian disebabkan oleh…
# ...
